# %%
C, B = map(int, input().split())

t = 0
Blist = [B]
while True:
    if C in Blist:
        print(t)
        break
    elif C > 200000:
        print(-1)
        break
    else:
        t += 1
        C += t
        Bnext = []
        for i in range(len(Blist)):
            Bnext.append(Blist[i]+1)
            Bnext.append(Blist[i]-1)
            Bnext.append(Blist[i]*2)
        Blist = Bnext
# Out:
# 11 1
# 6
